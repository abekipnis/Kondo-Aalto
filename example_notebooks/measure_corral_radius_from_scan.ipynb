# %%
from AaltoAtoms import CircCorralData
import os

# %%
p = "A220329.113009.dat"
dpath = r"Y:\labdata\Createc\STMDATA\Ag(111)\2022-03 Co Kondo corrals\03-29"

# %%
c = CircCorralData(os.path.join(dpath, p), p)

# %%
c.occupied = True
c.corral = True

c.subtract_plane()
c.get_region_centroids(diamond_size=3, sigmaclip=2, show=True)
c.get_corral_radius(0.9)
# Out:
# 	14 centroids
# 	Max height guess different from Gaussian fit on average by: 1.18 Å
# 	 A220329.113009.dat
# 	Central atom from Naive fit:  7.415822707442342 [56.55408889 57.85095366]
# 	Central atom from Gauss fit:  7.410765173407741 [56.10196314 57.38400641]
# 7.410765173407741
