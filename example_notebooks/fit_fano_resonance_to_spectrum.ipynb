# %%
from AaltoAtoms import read_vertfile, Spec, fit_data_fixed_vals, fit_data_w_times_residual
import matplotlib.pyplot as plt

# %%
f = r"Y:\labdata\Createc\STMDATA\Ag(111)\2022-03 Co Kondo corrals\04-08\A220408.110950.L0085.VERT"
plt.ion()
S = Spec(f)
S.clip_data(-40,40)
S.remove_background(degree=3)
S.fit_fano(marker1=-19, marker2=20, showfig=True, type_fit='wtimes')
# Out:
# [array([ 3.88352334e+00,  4.12508280e+00, -4.48242597e-09,  7.81986124e-01,
#          1.28560046e-01, -5.91783674e+00]),
#  array([[ 6.57467636e-13, -9.46633858e-12, -3.32778967e+00,
#          -7.04223346e-11,  1.51674384e-09,  7.66641593e-12]]),
#  -19,
#  20,
#  -11.48868,
#  -11.15493,
#  3.3277896673176]
