# %%
from AaltoAtoms import read_vertfile, Spec, fit_data_fixed_vals, fit_data_w_times_residual
import matplotlib.pyplot as plt

# %%
f = r"Y:\labdata\Createc\STMDATA\Ag(111)\2022-03 Co Kondo corrals\03-29\A220329.113106.VERT"
plt.ion()
Spec.fit_fano
Spec(f).fit_fano(marker1=-40, marker2=40, showfig=True)
# Out:
# [array([ 3.51857998e+00,  2.19338624e+01,  2.11326041e-01,  1.81048342e+02,
#         -1.60261222e+00,  3.32396863e+02]),
#  array([[ 6.10470732e-02,  9.25980652e-03,  3.59283128e-03,
#          -1.95490046e-01, -1.09406851e-02,  1.06953694e-01],
#         [ 9.25980652e-03,  1.48106015e-01,  6.73811806e-04,
#          -4.77304055e-02, -4.75425832e-03,  3.66891759e-01],
#         [ 3.59283128e-03,  6.73811806e-04,  2.41339327e-04,
#          -1.27460948e-02, -7.87261133e-04,  6.83559807e-03],
#         [-1.95490046e-01, -4.77304055e-02, -1.27460948e-02,
#           2.86572189e+00,  3.29386848e-02, -1.81579971e+00],
#         [-1.09406851e-02, -4.75425832e-03, -7.87261133e-04,
#           3.29386848e-02,  3.09704964e-03, -2.23390634e-02],
#         [ 1.06953694e-01,  3.66891759e-01,  6.83559807e-03,
#          -1.81579971e+00, -2.23390634e-02,  2.15027179e+00]]),
#  -40,
#  40,
#  -132.80223,
#  339.93198,
#  0.44070389597377746]
