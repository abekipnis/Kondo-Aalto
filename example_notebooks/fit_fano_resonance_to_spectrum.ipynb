# %%
from AaltoAtoms import read_vertfile, Spec, fit_data_fixed_vals, fit_data_w_times_residual
import ipympl
# %matplotlib widget

import matplotlib.pyplot as plt

# %%
f = "/Users/akipnis/Desktop/Aalto Atomic Scale Physics/Summer 2021 Corrals Exp data/Ag 2021-07-29 corral built/Line spectrum across corral/Createc2_210729.180059.L0025.VERT"
plt.ion()
Spec.fit_fano
Spec(f).fit_fano(marker1=-20, marker2=20, showfig=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# [array([ 6.36458528e+00,  1.19694056e+01,  3.13744940e-01,  1.09520279e+02,
#         -3.82351954e+00,  3.27872289e+02]),
#  array([[ 4.44804048e-02, -1.25558711e-02,  5.54737756e-03,
#          -3.41588145e-01, -2.04423160e-02,  1.69481170e-01],
#         [-1.25558711e-02,  1.06307288e-01, -2.23267222e-03,
#           1.94046679e-01,  8.24050513e-03,  1.82695446e-01],
#         [ 5.54737756e-03, -2.23267222e-03,  7.75726332e-04,
#          -4.90932492e-02, -3.03795884e-03,  2.26852562e-02],
#         [-3.41588145e-01,  1.94046679e-01, -4.90932492e-02,
#           4.85285613e+00,  1.90168702e-01, -2.34353183e+00],
#         [-2.04423160e-02,  8.24050513e-03, -3.03795884e-03,
#           1.90168702e-01,  1.35075053e-02, -8.79367556e-02],
#         [ 1.69481170e-01,  1.82695446e-01,  2.26852562e-02,
#          -2.34353183e+00, -8.79367556e-02,  2.07687949e+00]]),
#  -20,
# ...
