# %%
from AaltoAtoms import show_line_spectrum, CircCorralData
import os

# %%
dat = r"H:\Createc\STMDATA\Ag(111)\2022-05-16 Pc depositions\2022-05-16 H2Pc (2 min 300 C -130 C)\A220518.112711.dat"
dir = r"H:\Createc\STMDATA\Ag(111)\2022-05-16 Pc depositions\2022-05-16 H2Pc (2 min 300 C -130 C)"

#c = CircCorralData(dat, os.path.basename(dat), chan=0)
#c.occupied = True
#c.corral = True

#c.subtract_plane()
#c.get_region_centroids(percentile=99, show=True)
#c.get_corral_radius(0.9)
timestamp = '120319'
biasmin = -80
biasmax = 80

#c = CircCorralData(dat, os.path.basename(dat))

specs = show_line_spectrum(dat, dir, timestamp, biasmin, biasmax)
# Out:
# using channel 0 instead of channel 2!
