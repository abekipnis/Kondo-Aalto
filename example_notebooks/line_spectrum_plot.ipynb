# %%
from AaltoAtoms import show_line_spectrum, CircCorralData
import os

# %%
dat = r"Y:\labdata\Createc\STMDATA\Ag(111)\2022-05-16 Pc depositions\2022-05-25 second deposition after noise issue\8p08 nm corral\A220527.185403.dat"
dir = r"Y:\labdata\Createc\STMDATA\Ag(111)\2022-05-16 Pc depositions\2022-05-25 second deposition after noise issue\8p08 nm corral"
timestamp = '185837'
biasmin = -80
biasmax = 80

c = CircCorralData(dat, os.path.basename(dat))
# %matplotlib notebook
specs = show_line_spectrum(dat, dir, timestamp, biasmin, biasmax, look_at_scale=False, norm_mv=-67)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
plt.plot(specs[10].bias_mv[1:], np.diff(specs[20].current)/np.diff(specs[10].bias_mv))
plt.plot(specs[10].bias_mv, specs[20].dIdV)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
specs[10].__dict__.keys()
# Out:
# dict_keys(['fname', 'a', 'NPoints', 'VertPosX_DAC', 'VertPosY_DAC', 'ChannelList', 'Channelcount', 'OutchannelList', 'OutChannelCount', 'XPos_nm', 'YPos_nm', 'data', 'T_ADC2', 'T_ADC3', 'T_AUXADC6', 'T_AUXADC7', 'LockinAmpl', 'LockinFreq', 'FBLogiset', 'biasVoltage', 'bias_mv', 'current', 'dIdV', 'bias_offset'])

# %%
import matplotlib.pyplot as plt
[s.remove_background(3) for s in specs]
# Out:
# func:'remove_background' args:[(<AaltoAtoms.Kondo_data_analysis.read_vertfile.Spec object at 0x000001E33290CFA0>, 3), {}] took: 0.1640 sec
# func:'remove_background' args:[(<AaltoAtoms.Kondo_data_analysis.read_vertfile.Spec object at 0x000001E33290CE80>, 3), {}] took: 0.1610 sec
# func:'remove_background' args:[(<AaltoAtoms.Kondo_data_analysis.read_vertfile.Spec object at 0x000001E33290CE50>, 3), {}] took: 0.1631 sec
# func:'remove_background' args:[(<AaltoAtoms.Kondo_data_analysis.read_vertfile.Spec object at 0x000001E33290CF70>, 3), {}] took: 0.1640 sec
# func:'remove_background' args:[(<AaltoAtoms.Kondo_data_analysis.read_vertfile.Spec object at 0x000001E3329DAB80>, 3), {}] took: 0.1923 sec
# func:'remove_background' args:[(<AaltoAtoms.Kondo_data_analysis.read_vertfile.Spec object at 0x000001E3329DAB50>, 3), {}] took: 0.1966 sec
# func:'remove_background' args:[(<AaltoAtoms.Kondo_data_analysis.read_vertfile.Spec object at 0x000001E3329DAF10>, 3), {}] took: 0.1814 sec
# ...

# %%
idx = 122
[plt.plot(s.bias_mv, s.dIdV) for s in [specs[idx]]]
plt.xlim(-30,30)
specs[idx].fname
# Out:
# 'Y:\\labdata\\Createc\\STMDATA\\Ag(111)\\2022-03 Co Kondo corrals\\04-01\\A220401.011026.L0123.VERT'
