# %%
from AaltoAtoms import show_line_spectrum, CircCorralData
import os

# %%
dat = r"Y:\labdata\Createc\STMDATA\Ag(111)\2022-03 Co Kondo corrals\03-28\A220328.184752.dat"
c = CircCorralData(dat, os.path.basename(dat))
c.occupied = True
c.corral = True

c.subtract_plane()
c.get_region_centroids(diamond_size=3, sigmaclip=1.5, show=True)
c.get_corral_radius(0.9)
dir = r"Y:\labdata\Createc\STMDATA\Ag(111)\2022-03 Co Kondo corrals\03-28"
timestamp = '220328.184917'
biasmin = -80
biasmax = 80

c = CircCorralData(dat, os.path.basename(dat))

show_line_spectrum(dat, dir, timestamp, biasmin, biasmax)
# Out:
# 	12 centroids
# 	Max height guess different from Gaussian fit on average by: 0.44 Å
# 	 A220328.184752.dat
# 	Central atom from Naive fit:  2.9090719363168502 [58.25653706 58.59689403]
# 	Central atom from Gauss fit:  2.8992055413451405 [58.46024252 59.29324915]
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
