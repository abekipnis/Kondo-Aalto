# %%
from AaltoAtoms import show_line_spectrum, CircCorralData
import os

# %%
dat = r"Y:\labdata\Createc\STMDATA\Ag(111)\2022-03 Co Kondo corrals\4-12 Co-Co\A220412.132510.dat"
dir = r"Y:\labdata\Createc\STMDATA\Ag(111)\2022-03 Co Kondo corrals\4-12 Co-Co"

c = CircCorralData(dat, os.path.basename(dat), chan=0)
c.occupied = True
c.corral = True

c.subtract_plane()
c.get_region_centroids(percentile=99, show=True)
c.get_corral_radius(0.9)
timestamp = '132822.L'
biasmin = -80
biasmax = 80

c = CircCorralData(dat, os.path.basename(dat))

show_line_spectrum(dat, dir, timestamp, biasmin, biasmax)
# Out:
# 	17 centroids
# 	Max height guess different from Gaussian fit on average by: 0.39 Å
# 	 A220412.132510.dat
# 	Central atom from Naive fit:  3.8380418795321716 [67.09274018 60.38558653]
# 	Central atom from Gauss fit:  3.8368345085161204 [67.30644603 60.31920121]
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# saving figure was successful
