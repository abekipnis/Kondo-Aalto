# %%
from AaltoAtoms import show_line_spectrum

# %%
dat = r'Y:\labdata\Createc\STMDATA\Ag(111)\2022-03 Co Kondo corrals\03-21\1d\New folder\A220324.172432.dat'
dir = r'Y:\labdata\Createc\STMDATA\Ag(111)\2022-03 Co Kondo corrals\03-21\1d\New folder'
timestamp = '220324.172841'
biasmin = -80
biasmax = 80

show_line_spectrum(dat, dir, timestamp, biasmin, biasmax)
