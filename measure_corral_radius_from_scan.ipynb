# %%
from AaltoAtoms import CircCorralData
import os

# %%
p = "Createc2_210730.105015.dat"
dpath = "/Users/akipnis/Desktop/Aalto Atomic Scale Physics/Summer 2021 Corrals Exp data/Ag 2021-07-29 corral built/"

# %%
c = CircCorralData(os.path.join(dpath, p), p)

# %%
c.occupied = True
c.corral = True

c.subtract_plane()
c.get_region_centroids(diamond_size=5, sigmaclip=2, show=True)
c.get_corral_radius(1.5)
# Out:
# 	9 centroids
# 	Max height guess different from Gaussian fit on average by: 0.92 Å
# adding zeros back since nx != ny in image pixels
# 	 Createc2_210730.105015.dat
# 	Central atom from Naive fit:  2.4400086777008774 [61.18692847 74.02622401]
# 	Central atom from Gauss fit:  2.4336491505753712 [60.41248341 73.81830832]
# 2.4336491505753712
